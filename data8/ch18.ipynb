# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
year = np.array(['Second']*60 + ['Third']*40)
major = np.array(['Undeclared']*30 + ['Declared']*30 + ['Undeclared']*8 + ['Declared']*32)
students = Table().with_columns(
    'Year', year,
    'Major', major
)
students.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>Major</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
#             <td>Second</td> <td>Undeclared</td>
#         </tr>
#         <tr>
# ...

# %%
students.sample(10)
# Out:
# Year   | Major
# Second | Declared
# Second | Undeclared
# Second | Declared
# Second | Undeclared
# Third  | Declared
# Second | Undeclared
# Third  | Declared
# Second | Declared
# Second | Declared
# Third  | Declared

# %%
students.pivot('Major', 'Year')
# Out:
# Year   | Declared | Undeclared
# Second | 30       | 30
# Third  | 32       | 8

# %%
30 / (30 + 32)
# Out:
# 0.4838709677419355

# %%
0.004 * 0.99
# Out:
# 0.00396

# %%
0.996 * 0.005
# Out:
# 0.00498

# %%
(0.00396) / (0.00396 + 0.00498)
# Out:
# 0.44295302013422816

# %%
prior_probability_disease = 0.004
n_d = int(prior_probability_disease * 100000)
n_nd = 100000 - n_d
n_pos_d = int(0.99 * n_d)
n_neg_d = n_d - n_pos_d
n_pos_nd = int(0.005 * n_nd)
n_neg_nd = n_nd - n_pos_nd
condition = np.array(['Disease']*n_d + ['No Disease']*n_nd)
test_results_d = np.array(['Positive']*n_pos_d + ['Negative']*n_neg_d)
test_results_nd = np.array(['Positive']*n_pos_nd + ['Negative']*n_neg_nd)
test = np.append(test_results_d, test_results_nd)
t = Table().with_columns(
    'True Condition', condition,
    'Test Result', test
)
t
# Out:
# True Condition | Test Result
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# Disease        | Positive
# ... (99990 rows omitted)

# %%
t.pivot('Test Result', 'True Condition')
# Out:
# True Condition | Negative | Positive
# Disease        | 4        | 396
# No Disease     | 99102    | 498

# %%
prior_probability_disease = 0.05
n_d = int(prior_probability_disease * 100000)
n_nd = 100000 - n_d
n_pos_d = int(0.99 * n_d)
n_neg_d = n_d - n_pos_d
n_pos_nd = int(0.005 * n_nd)
n_neg_nd = n_nd - n_pos_nd
condition = np.array(['Disease']*n_d + ['No Disease']*n_nd)
test_results_d = np.array(['Positive']*n_pos_d + ['Negative']*n_neg_d)
test_results_nd = np.array(['Positive']*n_pos_nd + ['Negative']*n_neg_nd)
test = np.append(test_results_d, test_results_nd)
t = Table().with_columns(
    'True Condition', condition,
    'Test Result', test
)
t.pivot('Test Result', 'True Condition')
# Out:
# True Condition | Negative | Positive
# Disease        | 50       | 4950
# No Disease     | 94525    | 475
